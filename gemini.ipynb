# %% [markdown]
# <a href="https://colab.research.google.com/github/Harish-M-5/Develop-Gen-AI-Apps-with-Gemini-and-Streamlit-using-Google-skill-lab/blob/main/gemini.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import google.generativeai as genai
import json

genai.configure(api_key="YOUR_API_KEY")

def get_weather(city: str):
    return f"The weather in {city} is sunny."

model = genai.GenerativeModel(
    model_name="gemini-pro",
    tools=[get_weather]
)

response = model.generate_content(
    "What is the weather in Chennai?"
)

print(response)
