# %% [markdown]
# <a href="https://colab.research.google.com/github/Harish-M-5/Develop-Gen-AI-Apps-with-Gemini-and-Streamlit-using-Google-skill-lab/blob/main/prompt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
prompt = """
You are an AI assistant.
Explain Cloud Run in 5 bullet points.
"""

response = model.generate_content(prompt)
print(response.text)
